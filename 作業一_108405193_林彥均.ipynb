# %% [markdown]
# <a href="https://colab.research.google.com/github/JuneLin2001/ColabPlotting/blob/main/%E4%BD%9C%E6%A5%AD%E4%B8%80_108405193_%E6%9E%97%E5%BD%A5%E5%9D%87.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import matplotlib as mpl
import matplotlib.font_manager as fm
# !wget -O TaipeiSansTCBeta-Regular.ttf https://drive.google.com/uc?id=1eGAsTN1HBpJAkeVM57_C7ccp7hbgSz3_&export=download

fm.fontManager.addfont('TaipeiSansTCBeta-Regular.ttf')
mpl.rc('font', family='Taipei Sans TC Beta')
# Out:
# --2023-10-11 15:45:27--  https://drive.google.com/uc?id=1eGAsTN1HBpJAkeVM57_C7ccp7hbgSz3_
# Resolving drive.google.com (drive.google.com)... 142.250.152.102, 142.250.152.100, 142.250.152.139, ...
# Connecting to drive.google.com (drive.google.com)|142.250.152.102|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://doc-0k-9o-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/pa0i8nhpsrsrm6f2avbeus03oc54s5jb/1697039100000/02847987870453524430/*/1eGAsTN1HBpJAkeVM57_C7ccp7hbgSz3_?uuid=21acbdea-81b4-4e1e-8c11-afbbae1084da [following]
# ...
# --2023-10-11 15:45:31--  https://doc-0k-9o-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/pa0i8nhpsrsrm6f2avbeus03oc54s5jb/1697039100000/02847987870453524430/*/1eGAsTN1HBpJAkeVM57_C7ccp7hbgSz3_?uuid=21acbdea-81b4-4e1e-8c11-afbbae1084da
# Resolving doc-0k-9o-docs.googleusercontent.com (doc-0k-9o-docs.googleusercontent.com)... 142.250.148.132, 2607:f8b0:4001:c54::84
# ...

# %%
#臉型
x = [-3.34, -3.301, -3.62, -3.59, -2.8, -2.01 ,-1 ,0.119 ,1.29,2.3,3.12,3.30,3.523,3.24,3,2.7,1.82,-1.17,-1.75,-2.44,-3.34]
y = [2.76, 1.05, 0.093, -0.56, -1.37, -1.8 ,-2,-2.14,-2.1,-1.9,-1.2,-0.2,0.8,1.82,2.1,3.48,2.98,3.36,2.83,2.62,2.76]

#右耳
l=[2.63,2.69,2.12,2.63]
m=[2.87,2.26,2.62,2.87]

#左耳
e=[-3.064,-2.96,-2.5,-3.064]
f=[1.28,2.16,2,1.28]

#左眉毛
h=[-0.874,-2.01]
i=[1.088,0.56]

#右眉毛
j=[1.17,2.233]
k=[1.409,0.691]

#左眼
a =[-1.009,-1.35,-1.33,-1.13,-0.89,-1.009]
b =[0.473,0.314,-0.128,-0.287,0.064,0.473]

#右眼
c=[1.62,1.27,1.294,1.487,1.82,1.62]
d=[0.575,0.507,0.053,-0.139,0.348,0.575]

#鼻子
r=[-0.045,0.704]
s=[-0.241,-0.287]

#嘴巴
t=[-0.396,-0.045,0.272,0.76,1.23]
u=[-0.979,-0.854,-0.389,-0.673,-0.65]
v=[-0.045,0.2,0.55,0.76]
w=[-0.854,-1,-0.99,-0.673]


plt.title("當作業是畫函數圖形但你是個文組時\n我：", loc="left")

plt.plot(x, y,a,b,c,d,r,s,t,u,v,w,h,i,j,k,l,m,e,f, color='C0')


plt.xticks(())
plt.yticks(())
plt.show()

#窩不知道.jpg

# %%
import matplotlib.image as mpimg

import urllib.request
url = "https://i.imgur.com/CbIj7IF.png"
urllib.request.urlretrieve(url, "image.png")
image = mpimg.imread("image.png")
plt.imshow(image)
plt.axis('off')
plt.show()

#參考圖片
